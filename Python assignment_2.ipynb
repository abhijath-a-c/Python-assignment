# %%
#pattern 
for i in range(0,5):
    for j in range(0,i):
        print("*",end="")
    print("")
for i in range(5,0,-1):
    for j in range(0,i):
        print("*",end="")
    print("")
# Out:
# *
# **
# ***
# ****
# *****
# ****
# ***
# **
# *

# %%
#Reverse a word 
w=input("enter any word")
print(w[::-1])
# Out:
# enter any wordineuron
# norueni
